# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: anyio==4.8.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (4.8.0)
# Requirement already satisfied: appnope==0.1.4 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (0.1.4)
# Requirement already satisfied: argon2-cffi==23.1.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (23.1.0)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (21.2.0)
# Requirement already satisfied: arrow==1.3.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: asttokens==3.0.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (3.0.0)
# Requirement already satisfied: async-lru==2.0.4 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (2.0.4)
# Requirement already satisfied: attrs==25.1.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (25.1.0)
# Requirement already satisfied: babel==2.17.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (2.17.0)
# Requirement already satisfied: beautifulsoup4==4.13.3 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (4.13.3)
# Requirement already satisfied: bleach==6.2.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (6.2.0)
# Requirement already satisfied: causal-learn==0.1.4.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 12)) (0.1.4.0)
# Requirement already satisfied: causalml==0.15.2 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 13)) (0.15.2)
# Requirement already satisfied: certifi==2025.1.31 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 14)) (2025.1.31)
# Requirement already satisfied: cffi==1.17.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 15)) (1.17.1)
# Requirement already satisfied: charset-normalizer==3.4.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 16)) (3.4.1)
# Requirement already satisfied: clarabel==0.10.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 17)) (0.10.0)
# Requirement already satisfied: cloudpickle==3.1.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 18)) (3.1.1)
# Requirement already satisfied: comm==0.2.2 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 19)) (0.2.2)
# Requirement already satisfied: contourpy==1.3.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 20)) (1.3.1)
# Requirement already satisfied: cvxpy==1.6.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 21)) (1.6.0)
# Requirement already satisfied: cycler==0.12.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 22)) (0.12.1)
# Requirement already satisfied: Cython==0.29.34 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 23)) (0.29.34)
# Requirement already satisfied: debugpy==1.8.12 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 24)) (1.8.12)
# Requirement already satisfied: decorator==5.1.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 25)) (5.1.1)
# Requirement already satisfied: defusedxml==0.7.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 26)) (0.7.1)
# Requirement already satisfied: dill==0.3.9 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 27)) (0.3.9)
# Requirement already satisfied: dowhy==0.12 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 28)) (0.12)
# Requirement already satisfied: econml==0.15.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 29)) (0.15.1)
# Requirement already satisfied: exceptiongroup==1.2.2 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 30)) (1.2.2)
# Requirement already satisfied: executing==2.2.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 31)) (2.2.0)
# Requirement already satisfied: fastjsonschema==2.21.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 32)) (2.21.1)
# Requirement already satisfied: fonttools==4.55.8 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 33)) (4.55.8)
# Requirement already satisfied: forestci==0.6 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 34)) (0.6)
# Requirement already satisfied: fqdn==1.5.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 35)) (1.5.1)
# Requirement already satisfied: graphviz==0.20.3 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 36)) (0.20.3)
# Requirement already satisfied: h11==0.14.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 37)) (0.14.0)
# Requirement already satisfied: httpcore==1.0.7 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 38)) (1.0.7)
# Requirement already satisfied: httpx==0.28.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 39)) (0.28.1)
# Requirement already satisfied: idna==3.10 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 40)) (3.10)
# Requirement already satisfied: ipykernel==6.29.5 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 41)) (6.29.5)
# Requirement already satisfied: ipython==8.32.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 42)) (8.32.0)
# Requirement already satisfied: ipywidgets==8.1.5 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 43)) (8.1.5)
# Requirement already satisfied: isoduration==20.11.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 44)) (20.11.0)
# Requirement already satisfied: jedi==0.19.2 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 45)) (0.19.2)
# Requirement already satisfied: Jinja2==3.1.5 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 46)) (3.1.5)
# Requirement already satisfied: joblib==1.4.2 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 47)) (1.4.2)
# Requirement already satisfied: json5==0.10.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 48)) (0.10.0)
# Requirement already satisfied: jsonpointer==3.0.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 49)) (3.0.0)
# Requirement already satisfied: jsonschema==4.23.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 50)) (4.23.0)
# Requirement already satisfied: jsonschema-specifications==2024.10.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 51)) (2024.10.1)
# Requirement already satisfied: jupyter==1.1.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 52)) (1.1.1)
# Requirement already satisfied: jupyter-console==6.6.3 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 53)) (6.6.3)
# Requirement already satisfied: jupyter-events==0.12.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 54)) (0.12.0)
# Requirement already satisfied: jupyter-lsp==2.2.5 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 55)) (2.2.5)
# Requirement already satisfied: jupyter_client==8.6.3 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 56)) (8.6.3)
# Requirement already satisfied: jupyter_core==5.7.2 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 57)) (5.7.2)
# Requirement already satisfied: jupyter_server==2.15.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 58)) (2.15.0)
# Requirement already satisfied: jupyter_server_terminals==0.5.3 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 59)) (0.5.3)
# Requirement already satisfied: jupyterlab==4.3.5 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 60)) (4.3.5)
# Requirement already satisfied: jupyterlab_pygments==0.3.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 61)) (0.3.0)
# Requirement already satisfied: jupyterlab_server==2.27.3 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 62)) (2.27.3)
# Requirement already satisfied: jupyterlab_widgets==3.0.13 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 63)) (3.0.13)
# Requirement already satisfied: kiwisolver==1.4.8 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 64)) (1.4.8)
# Requirement already satisfied: lightgbm==4.5.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 65)) (4.5.0)
# Requirement already satisfied: llvmlite==0.44.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 66)) (0.44.0)
# Requirement already satisfied: MarkupSafe==3.0.2 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 67)) (3.0.2)
# Requirement already satisfied: matplotlib==3.10.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 68)) (3.10.0)
# Requirement already satisfied: matplotlib-inline==0.1.7 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 69)) (0.1.7)
# Requirement already satisfied: mistune==3.1.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 70)) (3.1.1)
# Requirement already satisfied: momentchi2==0.1.8 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 71)) (0.1.8)
# Requirement already satisfied: mpmath==1.3.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 72)) (1.3.0)
# Requirement already satisfied: multiprocess==0.70.17 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 73)) (0.70.17)
# Requirement already satisfied: nbclient==0.10.2 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 74)) (0.10.2)
# Requirement already satisfied: nbconvert==7.16.6 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 75)) (7.16.6)
# Requirement already satisfied: nbformat==5.10.4 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 76)) (5.10.4)
# Requirement already satisfied: nest-asyncio==1.6.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 77)) (1.6.0)
# Requirement already satisfied: networkx==3.4.2 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 78)) (3.4.2)
# Requirement already satisfied: notebook==7.3.2 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 79)) (7.3.2)
# Requirement already satisfied: notebook_shim==0.2.4 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 80)) (0.2.4)
# Requirement already satisfied: numba==0.61.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 81)) (0.61.0)
# Requirement already satisfied: numpy==1.26.4 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 82)) (1.26.4)
# Requirement already satisfied: osqp==0.6.7.post3 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 83)) (0.6.7.post3)
# Requirement already satisfied: overrides==7.7.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 84)) (7.7.0)
# Requirement already satisfied: packaging==24.2 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 85)) (24.2)
# Requirement already satisfied: pandas==2.2.3 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 86)) (2.2.3)
# Requirement already satisfied: pandocfilters==1.5.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 87)) (1.5.1)
# Requirement already satisfied: parso==0.8.4 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 88)) (0.8.4)
# Requirement already satisfied: pathos==0.2.9 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 89)) (0.2.9)
# Requirement already satisfied: patsy==1.0.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 90)) (1.0.1)
# Requirement already satisfied: pexpect==4.9.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 91)) (4.9.0)
# Requirement already satisfied: pillow==11.1.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 92)) (11.1.0)
# Requirement already satisfied: platformdirs==4.3.6 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 93)) (4.3.6)
# Requirement already satisfied: pox==0.3.5 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 94)) (0.3.5)
# Requirement already satisfied: ppft==1.7.6.9 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 95)) (1.7.6.9)
# Requirement already satisfied: progressbar2==4.5.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 96)) (4.5.0)
# Requirement already satisfied: prometheus_client==0.21.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 97)) (0.21.1)
# Requirement already satisfied: prompt_toolkit==3.0.50 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 98)) (3.0.50)
# Requirement already satisfied: psutil==6.1.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 99)) (6.1.1)
# Requirement already satisfied: ptyprocess==0.7.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 100)) (0.7.0)
# Requirement already satisfied: pure_eval==0.2.3 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 101)) (0.2.3)
# Requirement already satisfied: pycparser==2.22 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 102)) (2.22)
# Requirement already satisfied: pydot==3.0.4 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 103)) (3.0.4)
# Requirement already satisfied: pydotplus==2.0.2 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 104)) (2.0.2)
# Requirement already satisfied: pygam==0.9.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 105)) (0.9.1)
# Requirement already satisfied: Pygments==2.19.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 106)) (2.19.1)
# Requirement already satisfied: pyparsing==3.2.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 107)) (3.2.1)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 108)) (2.9.0.post0)
# Requirement already satisfied: python-json-logger==3.2.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 109)) (3.2.1)
# Requirement already satisfied: python-utils==3.9.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 110)) (3.9.1)
# Requirement already satisfied: pytz==2025.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 111)) (2025.1)
# Requirement already satisfied: PyYAML==6.0.2 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 112)) (6.0.2)
# Requirement already satisfied: pyzmq==26.2.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 113)) (26.2.1)
# Requirement already satisfied: qdldl==0.1.7.post5 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 114)) (0.1.7.post5)
# Requirement already satisfied: referencing==0.36.2 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 115)) (0.36.2)
# Requirement already satisfied: requests==2.32.3 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 116)) (2.32.3)
# Requirement already satisfied: rfc3339-validator==0.1.4 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 117)) (0.1.4)
# Requirement already satisfied: rfc3986-validator==0.1.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 118)) (0.1.1)
# Requirement already satisfied: rpds-py==0.22.3 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 119)) (0.22.3)
# Requirement already satisfied: scikit-learn==1.5.2 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 120)) (1.5.2)
# Requirement already satisfied: scipy==1.11.4 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 121)) (1.11.4)
# Requirement already satisfied: scs==3.2.7.post2 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 122)) (3.2.7.post2)
# Requirement already satisfied: seaborn==0.13.2 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 123)) (0.13.2)
# Requirement already satisfied: Send2Trash==1.8.3 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 124)) (1.8.3)
# Requirement already satisfied: shap==0.43.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 125)) (0.43.0)
# Requirement already satisfied: six==1.17.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 126)) (1.17.0)
# Requirement already satisfied: slicer==0.0.7 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 127)) (0.0.7)
# Requirement already satisfied: sniffio==1.3.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 128)) (1.3.1)
# Requirement already satisfied: soupsieve==2.6 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 129)) (2.6)
# Requirement already satisfied: sparse==0.15.5 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 130)) (0.15.5)
# Requirement already satisfied: stack-data==0.6.3 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 131)) (0.6.3)
# Requirement already satisfied: statsmodels==0.14.4 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 132)) (0.14.4)
# Requirement already satisfied: sympy==1.13.3 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 133)) (1.13.3)
# Requirement already satisfied: terminado==0.18.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 134)) (0.18.1)
# Requirement already satisfied: threadpoolctl==3.5.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 135)) (3.5.0)
# Requirement already satisfied: tinycss2==1.4.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 136)) (1.4.0)
# Requirement already satisfied: tomli==2.2.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 137)) (2.2.1)
# Requirement already satisfied: tornado==6.4.2 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 138)) (6.4.2)
# Requirement already satisfied: tqdm==4.67.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 139)) (4.67.1)
# Requirement already satisfied: traitlets==5.14.3 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 140)) (5.14.3)
# Requirement already satisfied: types-python-dateutil==2.9.0.20241206 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 141)) (2.9.0.20241206)
# Requirement already satisfied: typing_extensions==4.12.2 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 142)) (4.12.2)
# Requirement already satisfied: tzdata==2025.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 143)) (2025.1)
# Requirement already satisfied: uri-template==1.3.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 144)) (1.3.0)
# Requirement already satisfied: urllib3==2.3.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 145)) (2.3.0)
# Requirement already satisfied: wcwidth==0.2.13 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 146)) (0.2.13)
# Requirement already satisfied: webcolors==24.11.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 147)) (24.11.1)
# Requirement already satisfied: webencodings==0.5.1 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 148)) (0.5.1)
# Requirement already satisfied: websocket-client==1.8.0 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 149)) (1.8.0)
# Requirement already satisfied: widgetsnbextension==4.0.13 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 150)) (4.0.13)
# Requirement already satisfied: xgboost==2.1.3 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 151)) (2.1.3)
# Requirement already satisfied: pip>=10.0 in ./.venv/lib/python3.10/site-packages (from causalml==0.15.2->-r requirements.txt (line 13)) (23.0.1)
# Requirement already satisfied: setuptools>=40.8.0 in ./.venv/lib/python3.10/site-packages (from jupyterlab==4.3.5->-r requirements.txt (line 60)) (65.5.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0
# [notice] To update, run: pip install --upgrade pip

# %%
# %load_ext autoreload
# %autoreload 2
from causalml.inference.meta import LRSRegressor

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from xgboost import XGBRegressor
import warnings

from causalml.inference.meta import LRSRegressor
from causalml.inference.meta import XGBTRegressor, MLPTRegressor
from causalml.inference.meta import BaseXRegressor, BaseRRegressor, BaseSRegressor, BaseTRegressor
from causalml.match import NearestNeighborMatch, MatchOptimizer, create_table_one
from causalml.propensity import ElasticNetPropensityModel
from causalml.dataset import *
from causalml.metrics import *

warnings.filterwarnings('ignore')
plt.style.use('fivethirtyeight')

# %matplotlib inline

# %%
import importlib
print(importlib.metadata.version('causalml') )
# Out:
# 0.15.2

# %%
# Generate synthetic data using mode 1
y, X, treatment, tau, b, e = synthetic_data(mode=1, n=10000, p=8, sigma=1.0)

# %%
# Ready-to-use S-Learner using LinearRegression
learner_s = LRSRegressor()
ate_s = learner_s.estimate_ate(X=X, treatment=treatment, y=y)
print(ate_s)
print('ATE estimate: {:.03f}'.format(ate_s[0][0]))
print('ATE lower bound: {:.03f}'.format(ate_s[1][0]))
print('ATE upper bound: {:.03f}'.format(ate_s[2][0]))

# After calling estimate_ate, add pretrain=True flag to skip training
# This flag is applicable for other meta learner
ate_s = learner_s.estimate_ate(X=X, treatment=treatment, y=y, pretrain=True)
print(ate_s)
print('ATE estimate: {:.03f}'.format(ate_s[0][0]))
print('ATE lower bound: {:.03f}'.format(ate_s[1][0]))
print('ATE upper bound: {:.03f}'.format(ate_s[2][0]))
# Out:
# (array([0.68685887]), array([0.63855697]), array([0.73516077]))
# ATE estimate: 0.687
# ATE lower bound: 0.639
# ATE upper bound: 0.735
# (array([0.68685887]), array([0.63855697]), array([0.73516077]))
# ATE estimate: 0.687
# ATE lower bound: 0.639
# ATE upper bound: 0.735

# %%
# Ready-to-use T-Learner using XGB
learner_t = XGBTRegressor()
ate_t = learner_t.estimate_ate(X=X, treatment=treatment, y=y)
print('Using the ready-to-use XGBTRegressor class')
print(ate_t)

# Calling the Base Learner class and feeding in XGB
learner_t = BaseTRegressor(learner=XGBRegressor())
ate_t = learner_t.estimate_ate(X=X, treatment=treatment, y=y)
print('\nUsing the BaseTRegressor class and using XGB (same result):')
print(ate_t)

# Calling the Base Learner class and feeding in LinearRegression
learner_t = BaseTRegressor(learner=LinearRegression())
ate_t = learner_t.estimate_ate(X=X, treatment=treatment, y=y)
print('\nUsing the BaseTRegressor class and using Linear Regression (different result):')
print(ate_t)
# Out:
# Using the ready-to-use XGBTRegressor class
# (array([0.56787035]), array([0.54391019]), array([0.59183052]))
#
# Using the BaseTRegressor class and using XGB (same result):
# (array([0.56787035]), array([0.54391019]), array([0.59183052]))
#
# Using the BaseTRegressor class and using Linear Regression (different result):
# (array([0.67929973]), array([0.63861058]), array([0.71998888]))

# %%
# X Learner with propensity score input
# Calling the Base Learner class and feeding in XGB
learner_x = BaseXRegressor(learner=XGBRegressor())
ate_x = learner_x.estimate_ate(X=X, treatment=treatment, y=y, p=e)
print('Using the BaseXRegressor class and using XGB:')
print(ate_x)

# Calling the Base Learner class and feeding in LinearRegression
learner_x = BaseXRegressor(learner=LinearRegression())
ate_x = learner_x.estimate_ate(X=X, treatment=treatment, y=y, p=e)
print('\nUsing the BaseXRegressor class and using Linear Regression:')
print(ate_x)
# Out:
# Using the BaseXRegressor class and using XGB:
# (array([0.55599676]), array([0.53560684]), array([0.57638667]))
#
# Using the BaseXRegressor class and using Linear Regression:
# (array([0.67929973]), array([0.63861058]), array([0.71998888]))
